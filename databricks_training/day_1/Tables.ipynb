# %% [markdown]
# 1. pyspark datframe
# 2. CTAS
# 3. UI

# %%
# %sql
SELECT
  COUNT(*) - COUNT(order_id) AS order_id_nulls,
  COUNT(*) - COUNT(customerid) AS customerid_nulls,
  COUNT(*) - COUNT(transaction_id) AS transaction_id_nulls,
  COUNT(*) - COUNT(product_id) AS product_id_nulls,
  COUNT(*) - COUNT(quantity) AS quantity_nulls,
  COUNT(*) - COUNT(discount_amount) AS discount_amount_nulls,
  COUNT(*) - COUNT(total_amount) AS total_amount_nulls,
  COUNT(*) - COUNT(order_date) AS order_date_nulls
FROM acc_dev.nimish.sales
