# %% [markdown]
# ### Databricks Notebook

# %%
print('''hello''')
print('''world''')

# %%
# %sql

SELECT "abc"

# %%
# %sql
USE CATALOG acc_dev;
CREATE SCHEMA IF NOT EXISTS nimish;

# %%
# %sql
USE SCHEMA nimish;

# %%
# %sql
CREATE TABLE IF NOT EXISTS acc_dev.nimish.test (id INT PRIMARY KEY)

# %%
dbutils.fs.mkdirs("/Volumes/acc_dev/nimish/raw/image")

# %% [markdown]
# ![](/Volumes/acc_dev/nimish/raw/image/object-model.png)
