-- %%
GRANT SELECT ON TABLE acc_dev.nimish.cricket TO `account users`

-- %%
SHOW GRANTS ON TABLE acc_dev.nimish.cricket;

-- %%
GRANT CREATE FUNCTION ON SCHEMA acc_dev.nimish TO `account users`;

-- %%
REVOKE CREATE FUNCTION ON SCHEMA acc_dev.nimish FROM `account users`;

-- %%
SELECT * FROM naval_gold.agg
