-- %%
USE CATALOG acc_dev;
use schema nimish;

-- %%
create table if not exists emp (id int, name string, city string)

-- %%
insert into table emp values (1,'Nimish','NY'),(2,'Ravi','LA'),(3,'Ravi','LA')

-- %%
update emp set name = 'Nitin' where id = 1

-- %%
desc extended emp

-- %%
describe history emp

-- %%
describe detail emp

-- %%
insert into emp values (4,'John','LA'),(5,'W','LA');
select * from emp

-- %%
select * from emp version as of 3;
select * from emp version as of 4;

-- %%
DELETE FROM emp WHERE 1 = 1

-- %%
insert into acc_dev.naval.emp values (101,'Nimish','Hyd');
select * from acc_dev.naval.emp

-- %% [markdown]
-- ##Restore

-- %%
--restore table acc_dev.naval.emp

-- %%
SELECT * FROM emp
