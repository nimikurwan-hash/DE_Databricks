# %%
# %run "/Workspace/Users/nimikurwan@gmail.com/DE_Databricks/databricks_training/Day_3/includes"

# %%
df = spark.table(f"{catalog}.{schema}.{file_name}")

# %%
df1= df.dropDuplicates().dropna().drop("ingestion_date", "Path")

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.silver.{file_name}")

# %%
# %sql
SELECT * FROM dev.silver.sales
# Out:
# Databricks data profile. Run in Databricks to view.
