# %%
 # %skip
 
  Types of tables 
  1. managed table
     all the data + metadata 
  2. external table

# %%
# %skip 
# Types of View:
    1. Standard View
    2. temporary View

# %%
# %sql
CREATE OR REPLACE FUNCTION acc_dev.nimish.fullname (first_name STRING, last_name STRING) 
RETURNS STRING 
RETURN CONCAT(first_name, '-', last_name)

# %%
# %sql
SELECT acc_dev.nimish.fullname('nimish', 'Kumar')
