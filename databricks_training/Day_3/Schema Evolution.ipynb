# %%
data=([(1,'Virat'),(2,'Rohit')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.nimish.cricket")

# %%
data=([(3,'Sachin', 'Batsman'),(4,'Dhoni', 'WK')])
schema="id int, name string, role string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.option("mergeSchema", "true").mode("append").saveAsTable("acc_dev.nimish.cricket")

# %%
# %sql
SELECT * FROM acc_dev.nimish.cricket
