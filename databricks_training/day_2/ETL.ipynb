# %% [markdown]
# ## Step 1 : Reading or extracting

# %%
from pyspark.sql.functions import *

# %%
df= spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv", header=True, inferSchema=True)

# %% [markdown]
# ##Step2 : Transformation

# %% [markdown]
# Lazy evaluation
# Transformation
# read
# slelect
# filter
#
# Action (Create spark jobs)
#
# show
# display
# write

# %% [markdown]
# Transformation -> logical plan
# Action -> physical execution hence spark job creation

# %%
df.select("CustomerID","TransactionID")

# %%
df.select("CustomerID","TransactionID").display()

# %%
df.filter(df['CustomerID'] == "CUST0048").select("AccountType","TransactionType","CustomerID").display()

# %%
df.display()

# %% [markdown]
# Functions
# col,

# %%
df.withColumn("ingestion_time", current_timestamp()).display()
