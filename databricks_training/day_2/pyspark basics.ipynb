# %%
spark

# %%
data = [(1,'a'), (2,'b'), (3,'c')]
schema = ['id', 'name']

df = spark.createDataFrame(data, schema)

# %%
df.show(2)

# %%
df.display()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df

# %%
df.display()
df.printSchema()
df.show()
df.select('a', 'b').show()
df.select(df.a, df.b).show()

# %% [markdown]
# ### Reader API

# %%
df_sales=spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv",header=True,inferSchema=True)

# %%
df_sales.display()
df_sales.printSchema()

# %%
df_sales.write.saveAsTable("acc_dev.nimish.sales_py")

# %%
# %sql
SELECT * FROM acc_dev.nimish.sales_py

# %%
df_sales.write.mode("overwrite").saveAsTable("acc_dev.nimish.sales_py")

# %%
df_sales.write.mode("overwrite").parquet("/Volumes/acc_dev/naval/raw/parquet/sales_parquet")

# %%
df_household=spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet").write.saveAsTable("acc_dev.nimish.household_py")

# %%
# %sql
SELECT * FROM acc_dev.nimish.household_py

# %%
df_retail_orders = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")

# %%
df_retail_orders.display()
